# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
import sys
import cv2
import matplotlib
from subprocess import check_output
import tensorflow as tf
import matplotlib.pyplot as plt
import math as m

from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will switch to TensorFlow 2.x on the 27th of March, 2020.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from numpy import load
from numpy import save

large_img_arr = load('/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/large_img_arr.npy')
large_img_arr.shape
# Out:
# (10, 5000, 5000, 3)

# %%
num_of_small_img_per_dim = int(np.floor(5000/150))
for i in range(10):
  cropped_img_arr = np.array([])
  print(cropped_img_arr.shape)

  print('image:', i+1)
  #print(large_img_arr_2[i].shape)
  for x in range(num_of_small_img_per_dim):
    x_coordi = 150 * x
    for y in range(num_of_small_img_per_dim):
      y_coordi = 150 * y

      croped_img = large_img_arr[i,x_coordi:x_coordi+150,y_coordi:y_coordi+150,:]
      #print(croped_img.shape)
      croped_img = np.expand_dims(croped_img, axis=0)

 
      cropped_img_arr = np.vstack((cropped_img_arr,croped_img)) if cropped_img_arr.size else croped_img
  print(cropped_img_arr.shape)
  plt.imshow(cropped_img_arr[0,:,:,:])
  plt.show()
  save('/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/%dth_cropped_img_arr.npy'% (i), cropped_img_arr)
# Out:
# (0,)
# image: 1
# (1089, 150, 150, 3)
# (0,)
# image: 2
# (1089, 150, 150, 3)
# (0,)
# image: 3
# (1089, 150, 150, 3)
# (0,)
# image: 4
# (1089, 150, 150, 3)
# (0,)
# image: 5
# (1089, 150, 150, 3)
# (0,)
# image: 6
# (1089, 150, 150, 3)
# (0,)
# image: 7
# (1089, 150, 150, 3)
# (0,)
# image: 8
# (1089, 150, 150, 3)
# (0,)
# image: 9
# (1089, 150, 150, 3)
# (0,)
# image: 10
# (1089, 150, 150, 3)

# %%
import glob
from PIL import Image

import os
num_of_small_img_per_dim = int(np.floor(5000/150))
path = '/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/'
i=0
for filename in glob.glob(os.path.join(path, '*.tif')):
  i=i+1
  print(filename)
  im = Image.open(filename)
  #im.show()
  im_np = np.array(im)
  cropped_img_arr = np.array([])
  print(cropped_img_arr.shape)

  print('image:', i)
  #print(large_img_arr_2[i].shape)
  for x in range(num_of_small_img_per_dim):
    x_coordi = 150 * x
    for y in range(num_of_small_img_per_dim):
      y_coordi = 150 * y

      croped_img = im_np[x_coordi:x_coordi+150,y_coordi:y_coordi+150,:]
      #print(croped_img.shape)
      croped_img = np.expand_dims(croped_img, axis=0)

 
      cropped_img_arr = np.vstack((cropped_img_arr,croped_img)) if cropped_img_arr.size else croped_img
  print(cropped_img_arr.shape)
  save('/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/%dth_cropped_img_arr.npy'% (i), cropped_img_arr)
# Out:
# /content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-01_APPLICATION.tif
# (0,)
# image: 1
# (1089, 150, 150, 3)
# /content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-02-APPLICATION.tif
# (0,)
# image: 2
# (1089, 150, 150, 3)
# /content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-03_APPLICATION.tif
# (0,)
# image: 3
# (1089, 150, 150, 3)
# /content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-04_APPLICATION.tif
# (0,)
# image: 4
# (1089, 150, 150, 3)
# /content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-05_APPLICATION.tif
# (0,)
# image: 5
# (1089, 150, 150, 3)
# /content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-06_APPLICATION.tif
# (0,)
# ...

# %%
from numpy import save
# define data
# save to npy file
save('/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/%d_cropped_img_arr.npy'% (i), cropped_img_arr)

# %%
k = 2
save('/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/%d_cropped_img_arr.npy'% (k), cropped_img_arr)

# %%
num_of_small_img_per_dim = int(np.floor(5000/150))
cropped_img_arr = np.array([])
for i in range(large_img_arr_2.shape[0]):
  print('image:', i+1)
  #print(large_img_arr_2[i].shape)
  for x in range(num_of_small_img_per_dim):
    x_coordi = 150 * x
    for y in range(num_of_small_img_per_dim):
      y_coordi = 150 * y

      croped_img = large_img_arr_2[i,x_coordi:x_coordi+150,y_coordi:y_coordi+150,:]
      #print(croped_img.shape)
      croped_img = np.expand_dims(croped_img, axis=0)

 
      cropped_img_arr = np.vstack((cropped_img_arr,croped_img)) if cropped_img_arr.size else croped_img
  print(cropped_img_arr.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d7c7dcbb4bce> in <module>()
#       1 num_of_small_img_per_dim = int(np.floor(5000/150))
#       2 cropped_img_arr = np.array([])
# ----> 3 for i in range(large_img_arr_2.shape[0]):
#       4   print('image:', i+1)
#       5   #print(large_img_arr_2[i].shape)
#
# NameError: name 'large_img_arr_2' is not defined

# %%
from numpy import save
# define data
# save to npy file
save('/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/cropped_img_arr.npy', cropped_img_arr)

# %%
from numpy import load

cropped_img_arr = load('/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/cropped_img_arr.npy')
cropped_img_arr.shape

# %%
from matplotlib import cm
viridis = cm.get_cmap('tab10', 10)
predictions_testing = np.zeros([32,32])
for i in range(32):
  predictions_testing[i,:] = i
print(predictions_testing)
plt.imshow(predictions_testing,cmap =viridis )
plt.colorbar()
plt.show()
