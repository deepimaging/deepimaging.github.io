# %%
pip install tensorflow==2.0
# Out:
# ...
#      |████████████████████████████████| 86.3MB 57kB/s
# ...
#      |████████████████████████████████| 3.8MB 41.1MB/s
# ...
#      |████████████████████████████████| 450kB 55.0MB/s
# ...
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow~=2.1.0, but you'll have tensorflow 2.0.0 which is incompatible.
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow-addons~=0.7.0, but you'll have tensorflow-addons 0.8.3 which is incompatible.
# ...
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
#       Successfully uninstalled tensorflow-1.15.0
# ...

# %%
# if running in colab, this block chooses tf 2.0:
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
# https://www.pyimagesearch.com/2017/NUM_CLASSES/11/image-classification-with-keras-and-deep-learning/
# https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/
# https://machinelearningmastery.com/save-load-keras-deep-learning-models/
#https://www.learnopencv.com/image-classification-using-convolutional-neural-networks-in-keras/

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
import sys
import cv2
import matplotlib
from subprocess import check_output
import tensorflow as tf
import matplotlib.pyplot as plt
import math as m

from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from PIL import Image
im = Image.open('/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-10_APPLICATION.tif')
im.show()
imarray = np.array(im)
plt.imshow(imarray)
plt.show()

# %%
import glob
import os
large_img_arr = np.array([[[]]])
path = '/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/'
for filename in glob.glob(os.path.join(path, '*.tif')):
  print(filename)
  im = Image.open(filename)
  im.show()
  im_np = np.array(im)
  plt.imshow(im_np)
  plt.show()
  #im_np = np.array(im)
  im_np = np.expand_dims(im_np, axis=0)

  print(im_np.shape)
  #plt.imshow(im_np)
  #plt.show()
  large_img_arr = np.vstack((large_img_arr,im_np)) if large_img_arr.size else im_np
  print(large_img_arr.shape)
# Out:
# /content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-01_APPLICATION.tif
# (1, 5000, 5000, 3)
# (1, 5000, 5000, 3)
# /content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-02-APPLICATION.tif
# (1, 5000, 5000, 3)
# (2, 5000, 5000, 3)
# /content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-03_APPLICATION.tif
# (1, 5000, 5000, 3)
# (3, 5000, 5000, 3)
# /content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-04_APPLICATION.tif
# (1, 5000, 5000, 3)
# (4, 5000, 5000, 3)
# /content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/larger_images_10/CRC-Prim-HE-05_APPLICATION.tif
# (1, 5000, 5000, 3)
# (5, 5000, 5000, 3)
# ...

# %%
plt.imshow(large_img_arr[1])
plt.show()

# %%
from numpy import save
#import files
# define data
# save to npy file
save('/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/large_img_arr.npy', large_img_arr)
#files.download('/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/large_img_arr.npy')

# %%
from numpy import load

large_img_arr_2 = load('/content/drive/My Drive/Colab Notebooks/machine learning in imaging/final project/large_img_arr.npy')
large_img_arr_2.shape

# %%
cropped_img_arr = np.array([])
